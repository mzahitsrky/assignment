# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>
#
#
# ____

# %%
import pandas as pd
import numpy as np

# %%
ecom = pd.read_csv('data.csv',encoding= 'unicode_escape')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# **How many rows and columns are there?**

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# **Show the statistical measurements of ecom dataset**

# %%
ecom.describe().T
# Out:
#                count          mean          std       min       25%       50%  \
# Quantity    541909.0      9.552250   218.081158 -80995.00      1.00      3.00
# UnitPrice   541909.0      4.611114    96.759853 -11062.06      1.25      2.08
# CustomerID  406829.0  15287.690570  1713.600303  12346.00  13953.00  15152.00
#
#                  75%      max
# Quantity       10.00  80995.0
# UnitPrice       4.13  38970.0
# CustomerID  16791.00  18287.0

# %% [markdown]
# **What is the average Purchase Price?**

# %%
ecom["UnitPrice"].mean()
# Out:
# 4.611113626083471

# %% [markdown]
# **What were the highest and lowest purchase prices?**

# %%
ecom["UnitPrice"].min()
# Out:
# -11062.06

# %%
ecom["UnitPrice"].max()
# Out:
# 38970.0

# %% [markdown]
# **List the country names and number of records belongs to each country**

# %%
ecom["Country"].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# **How many records are as Country United Kingdom?**

# %%
ecom[ecom["Country"] == "United Kingdom"].count()
# Out:
# InvoiceNo      495478
# StockCode      495478
# Description    494024
# Quantity       495478
# InvoiceDate    495478
# UnitPrice      495478
# CustomerID     361878
# Country        495478
# dtype: int64

# %% [markdown]
# **Create a column named Total which shows the total amount of spend using UnitPrice and Quantity ?**

# %%
ecom.head(1)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom

# %%
ecom["Total"] = ecom["UnitPrice"] * ecom["Quantity"]

# %%
ecom["Total"]
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 541904    10.20
# 541905    12.60
# 541906    16.60
# 541907    16.60
# 541908    14.85
# Name: Total, Length: 541909, dtype: float64

# %% [markdown]
# **Show total spending amount according to the Countries**

# %%
ecom.groupby("Country")[["Total"]].sum()
# Out:
#                              Total
# Country
# Australia             1.370773e+05
# Austria               1.015432e+04
# Bahrain               5.484000e+02
# Belgium               4.091096e+04
# Brazil                1.143600e+03
# Canada                3.666380e+03
# Channel Islands       2.008629e+04
# Cyprus                1.294629e+04
# Czech Republic        7.077200e+02
# Denmark               1.876814e+04
# EIRE                  2.632768e+05
# European Community    1.291750e+03
# Finland               2.232674e+04
# France                1.974039e+05
# Germany               2.216982e+05
# Greece                4.710520e+03
# Hong Kong             1.011704e+04
# Iceland               4.310000e+03
# Israel                7.907820e+03
# Italy                 1.689051e+04
# Japan                 3.534062e+04
# Lebanon               1.693880e+03
# Lithuania             1.661060e+03
# Malta                 2.505470e+03
# Netherlands           2.846615e+05
# Norway                3.516346e+04
# Poland                7.213140e+03
# Portugal              2.936702e+04
# RSA                   1.002310e+03
# Saudi Arabia          1.311700e+02
# Singapore             9.120390e+03
# Spain                 5.477458e+04
# Sweden                3.659591e+04
# Switzerland           5.638535e+04
# USA                   1.730920e+03
# United Arab Emirates  1.902280e+03
# United Kingdom        8.187806e+06
# Unspecified           4.749790e+03

# %% [markdown]
# **Which Country spend least?**

# %%
ecom.groupby("Country")["Total"].sum().sort_values().head(1)
# Out:
# Country
# Saudi Arabia    131.17
# Name: Total, dtype: float64

# %% [markdown]
# **Calculate average of spending according to country with apply function?**

# %%
ecom.groupby("Country")["Total"].apply(lambda x : np.mean(x))
# Out:
# Country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  28.863158
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     32.122599
# European Community       21.176230
# Finland                  32.124806
# France                   23.069288
# Germany                  23.348943
# Greece                   32.263836
# Hong Kong                35.128611
# Iceland                  23.681319
# Israel                   26.625657
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# Poland                   21.152903
# Portugal                 19.333127
# RSA                      17.281207
# Saudi Arabia             13.117000
# Singapore                39.827031
# Spain                    21.624390
# Sweden                   79.211926
# Switzerland              28.164510
# USA                       5.948179
# United Arab Emirates     27.974706
# United Kingdom           16.525065
# Unspecified              10.649753
# Name: Total, dtype: float64

# %% [markdown]
# **Calculate average,min,max of spending according to country with agg function?**

# %%
ecom.groupby("Country")[["Total"]].agg([np.min,np.max,np.mean])
# Out:
#                           Total
#                            amin       amax        mean
# Country
# Australia               -425.00    1718.40  108.877895
# Austria                  -21.25     360.00   25.322494
# Bahrain                 -205.74     205.74   28.863158
# Belgium                  -19.95     165.00   19.773301
# Brazil                    15.00     175.20   35.737500
# Canada                     2.50     550.94   24.280662
# Channel Islands         -293.00     408.00   26.499063
# Cyprus                  -320.69     320.69   20.813971
# Czech Republic           -35.76      70.80   23.590667
# Denmark                  -59.80     428.40   48.247147
# EIRE                   -1917.00    2365.20   32.122599
# European Community        -8.50      60.00   21.176230
# Finland                  -80.00     551.20   32.124806
# France                 -8322.12    4161.06   23.069288
# Germany                 -599.50     876.00   23.348943
# Greece                   -50.00     175.20   32.263836
# Hong Kong              -2653.95    2653.95   35.128611
# Iceland                    5.04     249.60   23.681319
# Israel                  -136.00     350.40   26.625657
# Italy                    -89.55     300.00   21.034259
# Japan                  -1591.20    3794.40   98.716816
# Lebanon                   10.20     153.00   37.641778
# Lithuania                 13.20     122.40   47.458857
# Malta                   -130.00     455.00   19.728110
# Netherlands             -266.40    4992.00  120.059696
# Norway                  -376.50     700.00   32.378877
# Poland                   -39.80     120.00   21.152903
# Portugal               -1241.98    1241.98   19.333127
# RSA                        0.00      38.25   17.281207
# Saudi Arabia             -14.75      19.80   13.117000
# Singapore              -3949.32    3949.32   39.827031
# Spain                  -1715.85    1350.00   21.624390
# Sweden                 -1188.00    1188.00   79.211926
# Switzerland             -179.00     360.00   28.164510
# USA                      -74.88      81.36    5.948179
# United Arab Emirates       3.48     153.00   27.974706
# United Kingdom       -168469.60  168469.60   16.525065
# Unspecified                0.19      69.36   10.649753

# %% [markdown]
# **What is the max Total spending in whole dataset and show the records of that spending ?**

# %%
ecom["Total"].max()
# Out:
# 168469.6

# %%
ecom[ecom["Total"] == ecom["Total"].max()]
# Out:
#        InvoiceNo StockCode                  Description  Quantity  \
# 540421    581483     23843  PAPER CRAFT , LITTLE BIRDIE     80995
#
#            InvoiceDate  UnitPrice  CustomerID         Country     Total
# 540421  12/9/2011 9:15       2.08     16446.0  United Kingdom  168469.6

# %% [markdown]
# **How many people who live in Spain spend more than average Total ?**

# %%
len(ecom[(ecom["Country"] == "Spain") & (ecom["Total"] > ecom["Total"].mean())])
# Out:
# 728

# %% [markdown]
# **Convert datatype of InvoiceDate to datetime and assign it to new column name InvoiceDate2**

# %%
ecom["InvoiceDate2"] = pd.to_datetime(ecom["InvoiceDate"])

# %%
ecom.sample(10)
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 28824     538660     82582         AREA PATROLLED METAL SIGN        12
# 505890    579102     22699  ROSES REGENCY TEACUP AND SAUCER         12
# 177154    552042     21041   RED RETROSPOT OVEN GLOVE DOUBLE         6
# 266254    560249     22906   12 MESSAGE CARDS WITH ENVELOPES         3
# 292212    562542     22714              CARD BIRTHDAY COWBOY        12
# 477273    577055     22457   NATURAL SLATE HEART CHALKBOARD          6
# 196059    553768     21936          RED RETROSPOT PICNIC BAG         2
# 440575    574536     22197                    POPCORN HOLDER         1
# 141980    548533     21563      RED HEART SHAPE LOVE BUCKET          6
# 28209     538630     22672   FRENCH BATHROOM SIGN BLUE METAL        12
#
#              InvoiceDate  UnitPrice  CustomerID         Country  Total  \
# 28824   12/13/2010 15:37       2.10     15808.0  United Kingdom  25.20
# 505890  11/28/2011 11:33       2.95     14911.0            EIRE  35.40
# 177154     5/6/2011 9:00       2.95     13952.0  United Kingdom  17.70
# 266254   7/17/2011 12:26       1.65     17571.0  United Kingdom   4.95
# 292212    8/5/2011 15:40       0.42     17377.0  United Kingdom   5.04
# 477273  11/17/2011 14:22       2.95     15189.0  United Kingdom  17.70
# 196059   5/19/2011 10:47       5.79         NaN  United Kingdom  11.58
# 440575   11/4/2011 14:35       0.85     15707.0  United Kingdom   0.85
# 141980   3/31/2011 17:17       2.95     13883.0  United Kingdom  17.70
# 28209   12/13/2010 13:25       1.65     14565.0  United Kingdom  19.80
#
#               InvoiceDate2
# 28824  2010-12-13 15:37:00
# 505890 2011-11-28 11:33:00
# 177154 2011-05-06 09:00:00
# 266254 2011-07-17 12:26:00
# 292212 2011-08-05 15:40:00
# 477273 2011-11-17 14:22:00
# 196059 2011-05-19 10:47:00
# 440575 2011-11-04 14:35:00
# 141980 2011-03-31 17:17:00
# 28209  2010-12-13 13:25:00

# %% [markdown]
# **Take only date values (year-month-day) from InvoiceDate2 and assign it to a new column named date**

# %%
ecom["Date"] = pd.to_datetime(ecom["InvoiceDate2"].dt.date)
ecom["Date"]
# Out:
# 0        2010-12-01
# 1        2010-12-01
# 2        2010-12-01
# 3        2010-12-01
# 4        2010-12-01
#             ...
# 541904   2011-12-09
# 541905   2011-12-09
# 541906   2011-12-09
# 541907   2011-12-09
# 541908   2011-12-09
# Name: Date, Length: 541909, dtype: datetime64[ns]

# %% [markdown]
# **drop InvoiceDate2 and InvoiceDate columns permanently**

# %%
ecom.head(1)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Total  \
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom   15.3
#
#          InvoiceDate2       Date
# 0 2010-12-01 08:26:00 2010-12-01

# %%
ecom.drop(["InvoiceDate2","InvoiceDate"], axis=1, inplace=True)

# %%
ecom.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    UnitPrice  CustomerID         Country  Total       Date
# 0       2.55     17850.0  United Kingdom  15.30 2010-12-01
# 1       3.39     17850.0  United Kingdom  20.34 2010-12-01
# 2       2.75     17850.0  United Kingdom  22.00 2010-12-01
# 3       3.39     17850.0  United Kingdom  20.34 2010-12-01
# 4       3.39     17850.0  United Kingdom  20.34 2010-12-01

# %% [markdown]
# **Remove A, B, G and E from StockCode in first 5 rows of ecom dataframe with a string method**

# %%
ecom.StockCode[:5].str.replace("(\D+)","")
# Out:
# <ipython-input-131-f28290fccc49>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ecom.StockCode[:5].str.replace("(\D+)","")
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %% [markdown]
# **take only Total and date columns with loc and craete a new df named ecom2**

# %%
ecom2 = ecom.loc[:,["Total","Date"]]
ecom2
# Out:
#         Total       Date
# 0       15.30 2010-12-01
# 1       20.34 2010-12-01
# 2       22.00 2010-12-01
# 3       20.34 2010-12-01
# 4       20.34 2010-12-01
# ...       ...        ...
# 541904  10.20 2011-12-09
# 541905  12.60 2011-12-09
# 541906  16.60 2011-12-09
# 541907  16.60 2011-12-09
# 541908  14.85 2011-12-09
#
# [541909 rows x 2 columns]

# %% [markdown]
# **take only InvoiceNo, CustomerID and Total columns with iloc and craete a new df named ecom3**

# %%
ecom.head(1)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
#
#    UnitPrice  CustomerID         Country  Total       Date
# 0       2.55     17850.0  United Kingdom   15.3 2010-12-01

# %%
ecom3 = ecom.iloc[:,[0,5,7]]
ecom3
# Out:
#        InvoiceNo  CustomerID  Total
# 0         536365     17850.0  15.30
# 1         536365     17850.0  20.34
# 2         536365     17850.0  22.00
# 3         536365     17850.0  20.34
# 4         536365     17850.0  20.34
# ...          ...         ...    ...
# 541904    581587     12680.0  10.20
# 541905    581587     12680.0  12.60
# 541906    581587     12680.0  16.60
# 541907    581587     12680.0  16.60
# 541908    581587     12680.0  14.85
#
# [541909 rows x 3 columns]

# %% [markdown]
# **Combine ecom2 and ecom3 with concat**

# %%
pd.concat([ecom2,ecom3], axis=1)
# Out:
#         Total       Date InvoiceNo  CustomerID  Total
# 0       15.30 2010-12-01    536365     17850.0  15.30
# 1       20.34 2010-12-01    536365     17850.0  20.34
# 2       22.00 2010-12-01    536365     17850.0  22.00
# 3       20.34 2010-12-01    536365     17850.0  20.34
# 4       20.34 2010-12-01    536365     17850.0  20.34
# ...       ...        ...       ...         ...    ...
# 541904  10.20 2011-12-09    581587     12680.0  10.20
# 541905  12.60 2011-12-09    581587     12680.0  12.60
# 541906  16.60 2011-12-09    581587     12680.0  16.60
# 541907  16.60 2011-12-09    581587     12680.0  16.60
# 541908  14.85 2011-12-09    581587     12680.0  14.85
#
# [541909 rows x 5 columns]

# %% [markdown]
# **Combine ecom2 and ecom3 with merge. If memory error occurs take only first 400 rows from both DFs.**

# %%
pd.concat([ecom2.iloc[:400],ecom3.iloc[:400]], axis=1)
# Out:
#      Total       Date InvoiceNo  CustomerID  Total
# 0    15.30 2010-12-01    536365     17850.0  15.30
# 1    20.34 2010-12-01    536365     17850.0  20.34
# 2    22.00 2010-12-01    536365     17850.0  22.00
# 3    20.34 2010-12-01    536365     17850.0  20.34
# 4    20.34 2010-12-01    536365     17850.0  20.34
# ..     ...        ...       ...         ...    ...
# 395  15.00 2010-12-01    536404     16218.0  15.00
# 396  15.00 2010-12-01    536404     16218.0  15.00
# 397  15.00 2010-12-01    536404     16218.0  15.00
# 398  15.00 2010-12-01    536404     16218.0  15.00
# 399  15.00 2010-12-01    536404     16218.0  15.00
#
# [400 rows x 5 columns]

# %%
pd.merge(left= ecom2.iloc[:400], right= ecom3.iloc[:400], on="Total")
# Out:
#        Total       Date InvoiceNo  CustomerID
# 0      15.30 2010-12-01    536365     17850.0
# 1      15.30 2010-12-01    536373     17850.0
# 2      15.30 2010-12-01    536373     17850.0
# 3      15.30 2010-12-01    536375     17850.0
# 4      15.30 2010-12-01    536375     17850.0
# ...      ...        ...       ...         ...
# 2187   22.95 2010-12-01    536401     15862.0
# 2188   16.95 2010-12-01    536401     15862.0
# 2189   10.65 2010-12-01    536401     15862.0
# 2190   13.90 2010-12-01    536401     15862.0
# 2191  153.00 2010-12-01    536402     15513.0
#
# [2192 rows x 4 columns]

# %% [markdown]
# **Combine ecom2 and ecom3 with join (inner)**

# %%
ecom2.join(ecom3,lsuffix="_left", rsuffix="_right")
# Out:
#         Total_left       Date InvoiceNo  CustomerID  Total_right
# 0            15.30 2010-12-01    536365     17850.0        15.30
# 1            20.34 2010-12-01    536365     17850.0        20.34
# 2            22.00 2010-12-01    536365     17850.0        22.00
# 3            20.34 2010-12-01    536365     17850.0        20.34
# 4            20.34 2010-12-01    536365     17850.0        20.34
# ...            ...        ...       ...         ...          ...
# 541904       10.20 2011-12-09    581587     12680.0        10.20
# 541905       12.60 2011-12-09    581587     12680.0        12.60
# 541906       16.60 2011-12-09    581587     12680.0        16.60
# 541907       16.60 2011-12-09    581587     12680.0        16.60
# 541908       14.85 2011-12-09    581587     12680.0        14.85
#
# [541909 rows x 5 columns]

# %% [markdown]
# # Congrats!
